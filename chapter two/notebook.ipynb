# %% [markdown]
# # chapter 2: analyzing code perfomance

# %%
import numpy as np
import time
import timeit
from collections import Counter

# %% [markdown]
# ## code timing

# %%
# statistical mode of a list of numbers: slow method
def calculate_mode(numbers):
    results = {}
    for idx in numbers:
        if idx not in results:
            results[idx] = 1
        else:
            results[idx] += 1
    
    mode_values = []
    max_frequency = max(results.values())
    for key, value in results.items():
        if value == max_frequency:
            mode_values.append(key)
        
    return mode_values

# %%
# generating 100k random integers input into this function
random_ints = np.random.randint(1, 1_000_000, 1_000_000)

# %%
# measuring how long it takes
start = time.time()
calculate_mode(random_ints)
end = time.time()
print(end - start)
# Out:
# 0.6376652717590332

# %%
# %%timeit
calculate_mode(random_ints)
# Out:
# 537 ms ± 39.7 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# statistical mode of a list of numbers: fast method
def mode_using_counter(numbers):
    coun = Counter(numbers)
    return coun.most_common(1)[0][0]

# %%
# measuring how long it takes
start = time.time()
mode_using_counter(random_ints)
end = time.time()
print(end - start)
# Out:
# 0.5800940990447998

# %%
# %%timeit
mode_using_counter(random_ints)
# Out:
# 433 ms ± 7.87 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ## code profiling

# %% [markdown]
# ### cprofile

# %%
def mode_using_counter(n_ints):
    random_ints = np.random.randint(1, 100_000, n_ints)
    c = Counter(random_ints)
    return c.most_common(1)[0][0]

# %%
# %%prun
mode_using_counter(10_000_000)
# Out:
#          915 function calls (909 primitive calls) in 4.509 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    4.357    4.357    4.357    4.357 {built-in method _collections._count_elements}
#         2    0.137    0.069    0.137    0.069 {method '__exit__' of 'sqlite3.Connection' objects}
#         5    0.004    0.001    4.363    0.873 base_events.py:1962(_run_once)
#         1    0.003    0.003    0.003    0.003 {built-in method builtins.max}
#       2/1    0.002    0.001    4.367    4.367 <string>:1(<module>)
#         1    0.001    0.001    0.139    0.139 history.py:92(only_when_enabled)
#        14    0.000    0.000    0.000    0.000 socket.py:623(send)
#       2/1    0.000    0.000    4.368    4.368 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 iostream.py:127(_event_pipe_gc)
#         8    0.000    0.000    0.000    0.000 attrsettr.py:66(_get_attr_opt)
#   176/172    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         2    0.000    0.000    0.001    0.000 zmqstream.py:546(_run_callback)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        84    0.000    0.000    0.000    0.000 enum.py:1589(_get_value)
#         5    0.000    0.000    4.357    0.871 {method 'poll' of 'select.epoll' objects}
#         8    0.000    0.000    0.000    0.000 attrsettr.py:43(__getattr__)
#         8    0.000    0.000    0.000    0.000 socket.py:245(close)
#        16    0.000    0.000    0.000    0.000 enum.py:1596(__or__)
#        12    0.000    0.000    0.000    0.000 enum.py:1607(__and__)
#         1    0.000    0.000    0.138    0.138 history.py:1024(writeout_cache)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3631(set)
#         2    0.000    0.000    0.001    0.000 socket.py:700(send_multipart)
#         2    0.000    0.000    0.000    0.000 socket.py:771(recv_multipart)
#        38    0.000    0.000    0.000    0.000 enum.py:695(__call__)
#         5    0.000    0.000    4.358    0.872 selectors.py:435(select)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1527(_notify_observers)
#         2    0.000    0.000    0.000    0.000 traitlets.py:718(_validate)
#         1    0.000    0.000    0.000    0.000 {method 'execute' of 'sqlite3.Connection' objects}
#         4    0.000    0.000    0.001    0.000 zmqstream.py:573(_handle_events)
#         1    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         2    0.000    0.000    0.000    0.000 traitlets.py:727(_cross_validate)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1512(_notify_trait)
#        38    0.000    0.000    0.000    0.000 enum.py:1156(__new__)
#         1    0.000    0.000    0.000    0.000 inspect.py:3148(_bind)
#         6    0.000    0.000    0.002    0.000 {method 'run' of '_contextvars.Context' objects}
#         2    0.000    0.000    0.000    0.000 traitlets.py:3474(validate)
#         1    0.000    0.000    0.000    0.000 iostream.py:118(_run_event_pipe_gc)
#         2    0.000    0.000    0.000    0.000 traitlets.py:689(set)
#         1    0.000    0.000    0.000    0.000 __init__.py:673(update)
#         8    0.000    0.000    0.000    0.000 _weakrefset.py:115(discard)
#         6    0.000    0.000    0.002    0.000 events.py:87(_run)
#        13    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         7    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         4    0.000    0.000    0.000    0.000 zmqstream.py:653(_rebuild_io_state)
#         8    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#         1    0.000    0.000    0.000    0.000 decorator.py:200(fix)
#         2    0.000    0.000    0.001    0.000 iostream.py:278(_really_send)
#        11    0.000    0.000    0.000    0.000 threading.py:1136(is_alive)
#         2    0.000    0.000    0.001    0.000 iostream.py:157(_handle_event)
#        11    0.000    0.000    0.000    0.000 base_events.py:772(time)
#         1    0.000    0.000    0.137    0.137 history.py:1008(_writeout_input_cache)
#         6    0.000    0.000    0.000    0.000 typing.py:426(inner)
#        18    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         2    0.000    0.000    0.000    0.000 traitlets.py:3624(validate_elements)
#        26    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         4    0.000    0.000    0.000    0.000 zmqstream.py:676(_update_handler)
#         2    0.000    0.000    0.000    0.000 traitlets.py:708(__set__)
#         2    0.000    0.000    0.000    0.000 tasks.py:703(sleep)
#         6    0.000    0.000    0.000    0.000 selector_events.py:740(_process_events)
#         4    0.000    0.000    0.000    0.000 traitlets.py:676(__get__)
#         1    0.000    0.000    0.003    0.003 __init__.py:622(most_common)
#         2    0.000    0.000    0.001    0.000 zmqstream.py:614(_handle_recv)
#         1    0.000    0.000    0.000    0.000 contextlib.py:145(__exit__)
#         8    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         2    0.000    0.000    0.001    0.000 iostream.py:276(<lambda>)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:69(_wrapreduction)
#         2    0.000    0.000    0.000    0.000 traitlets.py:2304(validate)
#         8    0.000    0.000    0.000    0.000 context.py:283(_rm_socket)
#         4    0.000    0.000    0.000    0.000 traitlets.py:629(get)
#         1    0.000    0.000    0.000    0.000 asyncio.py:231(add_callback)
#         4    0.000    0.000    0.000    0.000 queue.py:115(empty)
#         1    0.000    0.000    0.000    0.000 history.py:1016(_writeout_output_cache)
#         2    0.000    0.000    0.000    0.000 typing.py:1665(__subclasscheck__)
#        16    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#         1    0.000    0.000    0.003    0.003 424893554.py:1(mode_using_counter)
#         1    0.000    0.000    0.000    0.000 <frozen abc>:117(__instancecheck__)
#         1    0.000    0.000    0.000    0.000 threading.py:312(_release_save)
#         3    0.000    0.000    0.000    0.000 events.py:36(__init__)
#         2    0.000    0.000    0.000    0.000 base_events.py:852(_call_soon)
#         1    0.000    0.000    0.003    0.003 heapq.py:523(nlargest)
#        20    0.000    0.000    0.000    0.000 typing.py:2371(cast)
#         1    0.000    0.000    0.000    0.000 inspect.py:2962(apply_defaults)
#         1    0.000    0.000    0.000    0.000 inspect.py:3290(bind)
#         8    0.000    0.000    0.000    0.000 _weakrefset.py:39(_remove)
#         1    0.000    0.000    0.139    0.139 decorator.py:232(fun)
#         9    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         4    0.000    0.000    0.000    0.000 typing.py:1443(__hash__)
#         8    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#         3    0.000    0.000    0.001    0.000 asyncio.py:206(_handle_events)
#         2    0.000    0.000    0.000    0.000 iostream.py:213(_is_master_process)
#         1    0.000    0.000    0.000    0.000 inspect.py:2909(args)
#         1    0.000    0.000    0.000    0.000 base_events.py:805(call_at)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1523(notify_change)
#         2    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         2    0.000    0.000    0.000    0.000 threading.py:306(__exit__)
#        11    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#         8    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:3328(prod)
#         2    0.000    0.000    0.000    0.000 typing.py:1374(__instancecheck__)
#         3    0.000    0.000    0.000    0.000 base_events.py:1947(_add_callback)
#         1    0.000    0.000    0.000    0.000 base_events.py:781(call_later)
#         4    0.000    0.000    0.000    0.000 zmqstream.py:532(sending)
#         1    0.000    0.000    0.000    0.000 events.py:157(cancel)
#         7    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 futures.py:310(_set_result_unless_cancelled)
#         8    0.000    0.000    0.000    0.000 socket.py:184(__del__)
#         4    0.000    0.000    0.000    0.000 {built-in method math.ceil}
#         1    0.000    0.000    0.000    0.000 threading.py:315(_acquire_restore)
#         2    0.000    0.000    0.000    0.000 base_events.py:823(call_soon)
#        11    0.000    0.000    0.000    0.000 {method 'is_done' of '_thread._ThreadHandle' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         2    0.000    0.000    0.000    0.000 traitlets.py:3486(validate_elements)
#         1    0.000    0.000    0.000    0.000 inspect.py:2932(kwargs)
#         2    0.000    0.000    0.000    0.000 threading.py:303(__enter__)
#         4    0.000    0.000    0.000    0.000 queue.py:267(_qsize)
#         2    0.000    0.000    0.000    0.000 <frozen abc>:121(__subclasscheck__)
#         1    0.000    0.000    0.000    0.000 contextlib.py:136(__enter__)
#         7    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 contextlib.py:108(__init__)
#         1    0.000    0.000    0.000    0.000 contextlib.py:303(helper)
#         1    0.000    0.000    0.000    0.000 base_events.py:457(create_future)
#         1    0.000    0.000    0.000    0.000 __init__.py:599(__init__)
#         2    0.000    0.000    0.000    0.000 iostream.py:216(_check_mp_mode)
#         3    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'set_result' of '_asyncio.Future' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         1    0.000    0.000    0.000    0.000 threading.py:631(clear)
#         6    0.000    0.000    0.000    0.000 zmqstream.py:528(receiving)
#         2    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method _contextvars.copy_context}
#         1    0.000    0.000    0.000    0.000 ioloop.py:750(_run_callback)
#         3    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#        10    0.000    0.000    0.000    0.000 inspect.py:2819(kind)
#         3    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#         1    0.000    0.000    0.000    0.000 events.py:113(__init__)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         2    0.000    0.000    0.000    0.000 {built-in method _asyncio.get_running_loop}
#        11    0.000    0.000    0.000    0.000 threading.py:605(is_set)
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#         2    0.000    0.000    0.000    0.000 history.py:1065(hold)
#         3    0.000    0.000    0.000    0.000 base_events.py:554(_check_closed)
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method _heapq.heappop}
#         1    0.000    0.000    0.000    0.000 threading.py:318(_is_owned)
#         1    0.000    0.000    0.000    0.000 zmqstream.py:684(<lambda>)
#         4    0.000    0.000    0.000    0.000 inspect.py:3102(parameters)
#         1    0.000    0.000    0.000    0.000 {built-in method math.isnan}
#         2    0.000    0.000    0.000    0.000 iostream.py:255(closed)
#         4    0.000    0.000    0.000    0.000 inspect.py:2807(name)
#         1    0.000    0.000    0.000    0.000 events.py:73(cancel)
#         5    0.000    0.000    0.000    0.000 base_events.py:2060(get_debug)
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'cancelled' of '_asyncio.Future' objects}
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:3323(_prod_dispatcher)
#         1    0.000    0.000    0.000    0.000 {built-in method _heapq.heappush}
#         1    0.000    0.000    0.000    0.000 inspect.py:2901(__init__)
#         1    0.000    0.000    0.000    0.000 base_events.py:1957(_timer_handle_cancelled)
