# %% [markdown]
# # Chapter one: What is good code

# %% [markdown]
# ## dont repeat yourself (dry) example

# %%
# suppose you ingesting 3 datasets
import pandas as pd

# %%
# opton 1: repeat yourself and import them separately
data = pd.read_csv("resources/autism.csv")
data = data.drop(["ID", "contry_of_res", "ethnicity"], axis=1)

data2 = pd.read_csv("resources/breast_cancer.csv")
data2 = data2.drop(["id", "Unnamed: 32"], axis=1)

data3 = pd.read_csv("resources/gld_price_data.csv")
data3 = data3.drop(["Date"], axis=1)

# %%
# option 2: robust function
def data_ingest(csv_file, columns_to_drop):
    data = pd.read_csv(csv_file)
    data = data.drop(columns_to_drop, axis=1)
    return data

# %% [markdown]
# ## modular code section

# %%
# ds project modular skeleton

# data ingestion
def load_data(file):
    pass

# data cleaner
def clean_data(input_data, max_length):
    pass

# plot
def plot_data(clean_data, x_axis_limit, line_width):
    pass

# feature engineering and selection
def feature_selection(cleaned_data):
    pass

# feature modelling and traininf
def model_and_training(X_train, y_train):
    pass

# evaluation
def model_evaluation(model, X_test, y_test):
    pass
